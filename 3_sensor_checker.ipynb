# %%
from kafka import KafkaConsumer, KafkaProducer
from config import kafka_config
import json

# Створення Kafka Producer
producer = KafkaProducer(
    bootstrap_servers=kafka_config['bootstrap_servers'],
    security_protocol=kafka_config['security_protocol'],
    sasl_mechanism=kafka_config['sasl_mechanism'],
    sasl_plain_username=kafka_config['username'],
    sasl_plain_password=kafka_config['password'],
    value_serializer=lambda v: json.dumps(v).encode('utf-8'),
    key_serializer=lambda v: json.dumps(v).encode('utf-8')
)


# Створення Kafka Consumer
consumer = KafkaConsumer(
    bootstrap_servers=kafka_config['bootstrap_servers'],
    security_protocol=kafka_config['security_protocol'],
    sasl_mechanism=kafka_config['sasl_mechanism'],
    sasl_plain_username=kafka_config['username'],
    sasl_plain_password=kafka_config['password'],
    value_deserializer=lambda v: json.loads(v.decode('utf-8')),
    key_deserializer=lambda v: json.loads(v.decode('utf-8')),
    auto_offset_reset='earliest',  # Зчитування повідомлень з початку
    enable_auto_commit=True,       # Автоматичне підтвердження зчитаних повідомлень
    group_id='my_consumer_group_3'   # Ідентифікатор групи споживачів
)

# Назва топіку
my_name = "vasyliev_v"
sensor_topic_name = f'{my_name}_building_sensors'
temp_alert_topic_name = f'{my_name}_temperature_alerts'
humidity_alert_topic_name = f'{my_name}_humidity_alerts'



# Підписка на топік з даними сенсорів
consumer.subscribe([sensor_topic_name])
print(f"Subscribed to topic '{sensor_topic_name}'")

# Обробка повідомлень з топіку з даними сенсорів
try:
    for message in consumer:
        print(f"Received message: {message.value} with key: {message.key}, partition {message.partition}")
        
		# Перевірка на перевищення порогу температури
		# Якщо температура більше 40 градусів
		# Створюємо повідомлення для відправки в топік з попередженням
        if message.value['temperature'] > 40:
            temp_alert_message = {
								"sensor_id": message.value['sensor_id'],
								"timestamp": message.value['timestamp'],
								"temperature": message.value['temperature'],
								"alert_message": "Temperature threshold exceeded"
								}
            print("Temperature alert triggered!")
            producer.send(temp_alert_topic_name, value=temp_alert_message)
            producer.flush()  # Очікування, поки всі повідомлення будуть відправлені
            print(f"Sent alert to topic '{temp_alert_topic_name}': {temp_alert_message}")
                  
		# Перевірка на перевищення порогу вологості
		# Якщо вологість більше 80% або менше 20%
		# Створюємо повідомлення для відправки в топік з попередженням
        if message.value['humidity'] > 80 or message.value['humidity'] < 20:
            humidity_alert_message = {
								"sensor_id": message.value['sensor_id'],
								"timestamp": message.value['timestamp'],
								"humidity": message.value['humidity'],
								"alert_message": "Humidity threshold exceeded"
								}
            print("Humidity alert triggered!")
            producer.send(humidity_alert_topic_name, value=humidity_alert_message)
            producer.flush()  # Очікування, поки всі повідомлення будуть відправлені
            print(f"Sent alert to topic '{humidity_alert_topic_name}': {humidity_alert_message}")		

except Exception as e:
    print(f"An error occurred: {e}")
finally:
    consumer.close()  # Закриття consumer
# Out:
# Subscribed to topic 'vasyliev_v_building_sensors'
# Received message: {'timestamp': 1743956450.6756322, 'sensor_id': 'sensor_24', 'temperature': 28, 'humidity': 45} with key: 1, partition 0
# Received message: {'timestamp': 1743956452.7360837, 'sensor_id': 'sensor_40', 'temperature': 39, 'humidity': 25} with key: 2, partition 0
# Received message: {'timestamp': 1743956454.7936566, 'sensor_id': 'sensor_5', 'temperature': 36, 'humidity': 33} with key: 3, partition 0
# Received message: {'timestamp': 1743956463.0320024, 'sensor_id': 'sensor_15', 'temperature': 31, 'humidity': 67} with key: 7, partition 0
# Received message: {'timestamp': 1743956465.0926013, 'sensor_id': 'sensor_23', 'temperature': 31, 'humidity': 58} with key: 8, partition 0
# Received message: {'timestamp': 1743956471.2761486, 'sensor_id': 'sensor_36', 'temperature': 27, 'humidity': 82} with key: 11, partition 0
# Humidity alert triggered!
# Sent alert to topic 'vasyliev_v_humidity_alerts': {'sensor_id': 'sensor_36', 'timestamp': 1743956471.2761486, 'humidity': 82, 'alert_message': 'Humidity threshold exceeded'}
# Received message: {'timestamp': 1743956473.3339326, 'sensor_id': 'sensor_26', 'temperature': 28, 'humidity': 83} with key: 12, partition 0
# Humidity alert triggered!
# Sent alert to topic 'vasyliev_v_humidity_alerts': {'sensor_id': 'sensor_26', 'timestamp': 1743956473.3339326, 'humidity': 83, 'alert_message': 'Humidity threshold exceeded'}
# Received message: {'timestamp': 1743956475.394437, 'sensor_id': 'sensor_9', 'temperature': 38, 'humidity': 60} with key: 13, partition 0
# Received message: {'timestamp': 1743956479.5122612, 'sensor_id': 'sensor_6', 'temperature': 39, 'humidity': 40} with key: 15, partition 0
# Received message: {'timestamp': 1743956485.6924238, 'sensor_id': 'sensor_27', 'temperature': 44, 'humidity': 23} with key: 18, partition 0
# Temperature alert triggered!
# Sent alert to topic 'vasyliev_v_temperature_alerts': {'sensor_id': 'sensor_27', 'timestamp': 1743956485.6924238, 'temperature': 44, 'alert_message': 'Temperature threshold exceeded'}
# Received message: {'timestamp': 1743956487.7525291, 'sensor_id': 'sensor_8', 'temperature': 37, 'humidity': 67} with key: 19, partition 0
# Received message: {'timestamp': 1743956448.2352583, 'sensor_id': 'sensor_31', 'temperature': 35, 'humidity': 80} with key: 0, partition 1
# Received message: {'timestamp': 1743956456.8524177, 'sensor_id': 'sensor_50', 'temperature': 27, 'humidity': 83} with key: 4, partition 1
# Humidity alert triggered!
# Sent alert to topic 'vasyliev_v_humidity_alerts': {'sensor_id': 'sensor_50', 'timestamp': 1743956456.8524177, 'humidity': 83, 'alert_message': 'Humidity threshold exceeded'}
# Received message: {'timestamp': 1743956458.9123697, 'sensor_id': 'sensor_26', 'temperature': 27, 'humidity': 77} with key: 5, partition 1
# Received message: {'timestamp': 1743956460.9721017, 'sensor_id': 'sensor_14', 'temperature': 31, 'humidity': 69} with key: 6, partition 1
# Received message: {'timestamp': 1743956467.1545258, 'sensor_id': 'sensor_5', 'temperature': 37, 'humidity': 20} with key: 9, partition 1
# Received message: {'timestamp': 1743956469.2156174, 'sensor_id': 'sensor_32', 'temperature': 37, 'humidity': 59} with key: 10, partition 1
# Received message: {'timestamp': 1743956477.4521203, 'sensor_id': 'sensor_33', 'temperature': 31, 'humidity': 27} with key: 14, partition 1
# Received message: {'timestamp': 1743956481.5716162, 'sensor_id': 'sensor_30', 'temperature': 28, 'humidity': 66} with key: 16, partition 1
# Received message: {'timestamp': 1743956483.6316502, 'sensor_id': 'sensor_41', 'temperature': 26, 'humidity': 83} with key: 17, partition 1
# Humidity alert triggered!
# Sent alert to topic 'vasyliev_v_humidity_alerts': {'sensor_id': 'sensor_41', 'timestamp': 1743956483.6316502, 'humidity': 83, 'alert_message': 'Humidity threshold exceeded'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 45
#      43 # Обробка повідомлень з топіку з даними сенсорів
#      44 try:
# ---> 45     for message in consumer:
#      46         print(f"Received message: {message.value} with key: {message.key}, partition {message.partition}")
#      48 		# Перевірка на перевищення порогу температури
#      49 		# Якщо температура більше 40 градусів
#      50 		# Створюємо повідомлення для відправки в топік з попередженням
#
# File ~/miniconda3/envs/ds_env/lib/python3.13/site-packages/kafka/consumer/group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File ~/miniconda3/envs/ds_env/lib/python3.13/site-packages/kafka/consumer/group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File ~/miniconda3/envs/ds_env/lib/python3.13/site-packages/kafka/consumer/group.py:693, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     691 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     692 while not self._closed:
# --> 693     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     694     if records:
#     695         return records
#
# File ~/miniconda3/envs/ds_env/lib/python3.13/site-packages/kafka/consumer/group.py:736, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     733 if records:
#     734     return records
# --> 736 self._client.poll(timeout_ms=inner_timeout_ms(self._coordinator.time_to_next_poll() * 1000))
#     737 # after the long poll, we should check whether the group needs to rebalance
#     738 # prior to returning data so that the group can stabilize faster
#     739 if self._coordinator.need_rejoin():
#
# File ~/miniconda3/envs/ds_env/lib/python3.13/site-packages/kafka/client_async.py:684, in KafkaClient.poll(self, timeout_ms, future)
#     677         timeout = min(
#     678             user_timeout_ms,
#     679             metadata_timeout_ms,
#     680             idle_connection_timeout_ms,
#     681             request_timeout_ms)
#     682         timeout = max(0, timeout)  # avoid negative timeouts
# --> 684     self._poll(timeout / 1000)
#     686 # called without the lock to avoid deadlock potential
#     687 # if handlers need to acquire locks
#     688 responses.extend(self._fire_pending_completed_requests())
#
# File ~/miniconda3/envs/ds_env/lib/python3.13/site-packages/kafka/client_async.py:727, in KafkaClient._poll(self, timeout)
#     724 self._register_send_sockets()
#     726 start_select = time.time()
# --> 727 ready = self._selector.select(timeout)
#     728 end_select = time.time()
#     729 if self._sensors:
#
# File ~/miniconda3/envs/ds_env/lib/python3.13/selectors.py:452, in EpollSelector.select(self, timeout)
#     450 ready = []
#     451 try:
# --> 452     fd_event_list = self._selector.poll(timeout, max_ev)
#     453 except InterruptedError:
#     454     return ready
#
# KeyboardInterrupt:
